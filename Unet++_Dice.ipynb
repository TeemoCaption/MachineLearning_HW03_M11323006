# %% [markdown]
# ##### Copyright 2019 The TensorFlow Authors.
#
# Licensed under the Apache License, Version 2.0 (the "License");

# %% [markdown]
# # 图像分割

# %%
# !pip install git+https://github.com/tensorflow/examples.git
# Out:
# Collecting git+https://github.com/tensorflow/examples.git
#   Cloning https://github.com/tensorflow/examples.git to /tmp/pip-req-build-ld3uez23
#   Running command git clone --filter=blob:none --quiet https://github.com/tensorflow/examples.git /tmp/pip-req-build-ld3uez23
#   Resolved https://github.com/tensorflow/examples.git to commit 3c7435733a9162481df350e57c53e58d2a705e4d
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from tensorflow-examples==0.1746868094.345130988853936603129253091149118257392589495885) (1.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from tensorflow-examples==0.1746868094.345130988853936603129253091149118257392589495885) (1.17.0)
# Building wheels for collected packages: tensorflow-examples
#   Building wheel for tensorflow-examples (setup.py) ... done
#   Created wheel for tensorflow-examples: filename=tensorflow_examples-0.1746868094.345130988853936603129253091149118257392589495885-py3-none-any.whl size=301646 sha256=be76804c87774953d4277054864d4b9c4894f3f592ca53dcecac07e139e6a3ff
#   Stored in directory: /tmp/pip-ephem-wheel-cache-kyuk7si9/wheels/91/9b/e8/6ae2ecc930bd726c578e35b313e987a687bc5ce03c3a42c2d5
# Successfully built tensorflow-examples
# Installing collected packages: tensorflow-examples
# Successfully installed tensorflow-examples-0.1746868094.345130988853936603129253091149118257392589495885

# %%
import tensorflow as tf
import os
from tensorflow_examples.models.pix2pix import pix2pix

from IPython.display import clear_output
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import numpy as np
from tensorflow import TensorSpec

# %%
from google.colab import drive
drive.mount('/content/drive')


from google.colab import drive
import os

drive.mount('/content/drive', force_remount=True)

# 輸入資料集路徑
#custom_dir = input("請貼上你的資料集資料夾完整路徑（如 /content/drive/MyDrive/...）：\n")

# 確認資料夾存在
# if not os.path.isdir(custom_dir):
#     raise FileNotFoundError(f"找不到資料夾：{custom_dir}，請確認路徑拼寫正確並已掛載雲端硬碟！")

#BASE_DIR = custom_dir
BASE_DIR = '/content/drive/MyDrive/Colab Notebooks/雲科機器學習課程/作業三/ETT dataset'
print(f"資料夾設定成功：{BASE_DIR}")


# 超參數
IMG_SIZE   = 256
BATCH_SIZE = 16
AUTOTUNE   = tf.data.AUTOTUNE
NUM_CLASSES = 3
NUM_FOLDS  = 5
# Out:
# Mounted at /content/drive
# Mounted at /content/drive
# 資料夾設定成功：/content/drive/MyDrive/Colab Notebooks/雲科機器學習課程/作業三/ETT dataset

# %%
# 圖片增強函數
class Augment(tf.keras.layers.Layer):
  def __init__(self, seed=42):
    super().__init__()
    self.augment_inputs = tf.keras.layers.RandomFlip(mode="horizontal", seed=seed)
    self.augment_labels = tf.keras.layers.RandomFlip(mode="horizontal", seed=seed)

  def call(self, inputs, labels):
    inputs = self.augment_inputs(inputs)
    labels = self.augment_labels(labels)
    return inputs, labels

augment_layer = Augment(seed=123)

# %%
# 讀檔 + normalize
def load_and_normalize(image_path, mask_path):
  """
  讀取單張影像與遮罩
  img_path  : tf.string，影像檔路徑
  mask_path : tf.string，遮罩檔路徑
  return    : (image, mask)；image 為 float32、mask 為 int32
  """
  # 讀影像
  img = tf.io.read_file(image_path)
  img = tf.image.decode_png(img, channels=3)
  img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
  img = tf.cast(img, tf.float32) / 255.0

  # 讀遮罩（假設單通道 png，像素值=類別 ID）
  msk = tf.io.read_file(mask_path)
  msk = tf.image.decode_png(msk, channels=1)
  msk = tf.image.resize(msk, [IMG_SIZE, IMG_SIZE], method="nearest")
  msk = tf.cast(msk, tf.int32)  # 確保是整數型

  return img, msk

# %%
def parse_image_mask(image_path, mask_path):
    # 圖片處理
    image = tf.io.read_file(image_path)
    image = tf.image.decode_png(image, channels=3)           # RGB
    image = tf.image.resize(image, [IMG_SIZE, IMG_SIZE])
    image = tf.cast(image, tf.float32) / 255.0               # 正規化到 [0,1]

    # 遮罩處理
    mask = tf.io.read_file(mask_path)
    mask = tf.image.decode_png(mask, channels=1)             # 灰階單通道
    mask = tf.image.resize(mask, [IMG_SIZE, IMG_SIZE])
    mask = tf.cast(mask, tf.float32) / 255.0

    # 將所有非 0 的 pixel 當作前景（氣管內管）
    mask = tf.where(mask > 0, 1.0, 0.0)    # 產生 0.0 / 1.0
    mask = tf.cast(mask, tf.float32)      # 確保 float32
    return image, mask


def augment(image, mask):
    mask = tf.cast(mask, tf.float32)  # 統一型別，跟 image 一樣
    stacked = tf.concat([image, mask], axis=-1)   # shape=(H,W,4)
    flipped = tf.image.random_flip_left_right(stacked)
    image_aug = flipped[..., :3]
    mask_aug  = flipped[..., 3:]
    return image_aug, mask_aug

def build_dataset(image_dir, mask_dir, augment_data=False):
    img_paths  = sorted([f"{image_dir}/{f}" for f in tf.io.gfile.listdir(image_dir)])
    mask_paths = sorted([f"{mask_dir}/{f}"  for f in tf.io.gfile.listdir(mask_dir)])

    ds = tf.data.Dataset.from_tensor_slices((img_paths, mask_paths))
    ds = ds.map(lambda i, m: parse_image_mask(i, m), num_parallel_calls=AUTOTUNE)
    if augment_data:
        ds = ds.map(lambda i, m: augment(i, m), num_parallel_calls=AUTOTUNE)

    return ds

# %% [markdown]
# 呈现数据集中的图像样本及其对应的掩码：

# %%
def plot_batch(image_batch, mask_batch, count=3):
    for i in range(min(count, image_batch.shape[0])):
        image = image_batch[i]
        mask  = mask_batch[i]

        # 調整 image 的顯示格式
        image = tf.cast(image, tf.float32)
        if tf.reduce_max(image) <= 1.0:
            image = image * 255.0
        image = tf.clip_by_value(image, 0, 255)
        image = tf.cast(image, tf.uint8)

        # squeeze 掉 mask 的通道
        if mask.ndim == 3:
            mask = tf.squeeze(mask, axis=-1)

        fig, axs = plt.subplots(1, 3, figsize=(12, 4))

        axs[0].imshow(image.numpy())
        axs[0].set_title("Image")

        axs[1].imshow(mask.numpy(), cmap='gray')
        axs[1].set_title("Ground Truth")

        axs[2].imshow(mask.numpy(), cmap='gray')
        axs[2].set_title("Prediction (test function)")

        for ax in axs:
            ax.axis("off")
        plt.tight_layout()
        plt.show()

# %%
train_ds= build_dataset(f"{BASE_DIR}/Fold{1}/train",
                             f"{BASE_DIR}/Fold{1}/trainannot",
                             augment_data=True).batch(BATCH_SIZE)
for image_batch, mask_batch in train_ds.take(1):  # 抓一個 batch
    plot_batch(image_batch, mask_batch, count=3)  # 顯示前三張圖

# %% [markdown]
# ## 建立模型

# %%
base_model = tf.keras.applications.MobileNetV2(input_shape=[256, 256, 3], include_top=False)

# Use the activations of these layers
layer_names = [
    'block_1_expand_relu',   # 64x64
    'block_3_expand_relu',   # 32x32
    'block_6_expand_relu',   # 16x16
    'block_13_expand_relu',  # 8x8
    'block_16_project',      # 4x4
]
base_model_outputs = [base_model.get_layer(name).output for name in layer_names]

# Create the feature extraction model
down_stack = tf.keras.Model(inputs=base_model.input, outputs=base_model_outputs)

down_stack.trainable = False
# Out:
# <ipython-input-9-e7f2f656cbe8>:1: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = tf.keras.applications.MobileNetV2(input_shape=[256, 256, 3], include_top=False)
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# 解码器/上采样器只是在 TensorFlow 示例中实现的一系列上采样块：

# %%
up_stack = [
    pix2pix.upsample(512, 3),  # 4x4 -> 8x8
    pix2pix.upsample(256, 3),  # 8x8 -> 16x16
    pix2pix.upsample(128, 3),  # 16x16 -> 32x32
    pix2pix.upsample(64, 3),   # 32x32 -> 64x64
]

# %%
def conv_block(x, filters, name=None):
    x = tf.keras.layers.Conv2D(filters, (3, 3), padding='same', activation='relu', name=f'{name}_conv1')(x)
    x = tf.keras.layers.BatchNormalization(name=f'{name}_bn1')(x)
    x = tf.keras.layers.Conv2D(filters, (3, 3), padding='same', activation='relu', name=f'{name}_conv2')(x)
    x = tf.keras.layers.BatchNormalization(name=f'{name}_bn2')(x)
    return x

def unetpp_model(input_shape=(256, 256, 3), num_classes=1):
    inputs = tf.keras.Input(shape=input_shape)

    # --------- Encoder：MobileNetV2 ---------
    base_model = tf.keras.applications.MobileNetV2(input_tensor=inputs,
                                                   include_top=False,
                                                   weights='imagenet')

    # 提取 Encoder 中間層特徵（用於跳接）
    skip_names = [
        'block_1_expand_relu',   # 64x64
        'block_3_expand_relu',   # 32x32
        'block_6_expand_relu',   # 16x16
        'block_13_expand_relu',  # 8x8
        'block_16_project'       # 4x4 (deepest)
    ]
    skips = [base_model.get_layer(name).output for name in skip_names]
    encoder = tf.keras.Model(inputs=inputs, outputs=skips)

    x0_0, x1_0, x2_0, x3_0, x4_0 = encoder(inputs)

    # --------- Decoder with Nested Connections ---------
    x0_1 = conv_block(tf.keras.layers.Concatenate()([
        x0_0,
        tf.keras.layers.UpSampling2D(size=(2, 2))(x1_0)
    ]), 32, name='x0_1')

    x1_1 = conv_block(tf.keras.layers.Concatenate()([
        x1_0,
        tf.keras.layers.UpSampling2D(size=(2, 2))(x2_0)
    ]), 64, name='x1_1')

    x0_2 = conv_block(tf.keras.layers.Concatenate()([
        x0_0, x0_1,
        tf.keras.layers.UpSampling2D(size=(2, 2))(x1_1)
    ]), 32, name='x0_2')

    # --------- Output Layer ---------
    output = tf.keras.layers.UpSampling2D(size=(2, 2))(x0_2)  # 128 -> 256
    output = tf.keras.layers.Conv2D(num_classes, (1, 1), activation='sigmoid', name='final')(output)

    return tf.keras.Model(inputs=inputs, outputs=output)

# %%
# 全域宣告：1 公分 = 72 像素
P = 72.0

class MeanErrorCM(tf.keras.metrics.Metric):
    def __init__(self, name='mean_error_cm', **kwargs):
        super().__init__(name=name, **kwargs)
        self.total_error = self.add_weight(name='total_error', initializer='zeros')
        self.count       = self.add_weight(name='count', initializer='zeros')

    def update_state(self, y_true, y_pred, sample_weight=None):
        # 先把 y_true 轉成 float32
        y_true = tf.cast(y_true, y_pred.dtype)
        # 像素誤差 ÷ P → 公分誤差
        error_px = tf.abs(y_true - y_pred)
        error_cm = error_px / P
        self.total_error.assign_add(tf.reduce_sum(error_cm))
        self.count.assign_add(tf.cast(tf.size(error_cm), tf.float32))

    def result(self):
        return self.total_error / (self.count + 1e-8)

    def reset_states(self):
        self.total_error.assign(0.)
        self.count.assign(0.)


class AccuracyWithinThreshold(tf.keras.metrics.Metric):
    def __init__(self, threshold_cm=0.5, name='acc_within_threshold', **kwargs):
        super().__init__(name=name, **kwargs)
        self.threshold_cm = threshold_cm
        self.correct = self.add_weight(name='correct', initializer='zeros')
        self.total   = self.add_weight(name='total', initializer='zeros')

    def _extract_endpoint(self, mask):
      mask = tf.squeeze(mask, axis=-1)
      mask = tf.cast(mask, tf.float32)
      # 加入一個中繼張量，然後 cast 成 int32
      raw_indices = tf.where(mask > 0.5)
      indices     = tf.cast(raw_indices, tf.int32)

      def no_fg():
          return tf.constant([-1.0, -1.0], dtype=tf.float32)

      def has_fg():
          # indices[:,0] 代表 y 座標
          # output_type 直接指定為 tf.int32
          max_y_idx = tf.argmax(indices[:, 0], output_type=tf.int32)

          # 取出 (x, y) 並轉成 float32
          endpoint = tf.cast(indices[max_y_idx][::-1], tf.float32)
          return endpoint

      return tf.cond(tf.shape(indices)[0] == 0, no_fg, has_fg)


    def update_state(self, y_true, y_pred, sample_weight=None):
        def compute_sample_accuracy(args):
            gt_mask, pred_mask = args
            gt_point = self._extract_endpoint(gt_mask)
            pred_point = self._extract_endpoint(pred_mask)

            # 判斷是否為有效點（不是 [-1, -1]）
            is_valid = tf.reduce_all(gt_point >= 0) & tf.reduce_all(pred_point >= 0)

            def compute_accuracy():
                err_px = tf.norm(gt_point - pred_point)
                err_cm = err_px / P
                return tf.cast(err_cm <= self.threshold_cm, tf.float32)

            return tf.cond(is_valid, compute_accuracy, lambda: tf.constant(-1.0))  # 無效標記為 -1

        correctness_batch = tf.map_fn(
          compute_sample_accuracy,
          (y_true, y_pred),
          fn_output_signature=TensorSpec(shape=(), dtype=tf.float32)
        )

        # 過濾掉無效樣本（== -1）
        # 直接過濾出 >= 0 的項目
        valid_values = tf.boolean_mask(correctness_batch, correctness_batch >= 0.0)

        self.correct.assign_add(tf.reduce_sum(valid_values))
        self.total.assign_add(tf.cast(tf.shape(valid_values)[0], tf.float32))

    def result(self):
        return self.correct / (self.total + 1e-8)

    def reset_states(self):
        self.correct.assign(0.0)
        self.total.assign(0.0)

# 1. 建立一個 callback，專門拆 MeanIoU 的結果
class PerClassIoUCallback(tf.keras.callbacks.Callback):
    def __init__(self, mean_iou_metric):
        super().__init__()
        self.mean_iou = mean_iou_metric

    def on_epoch_begin(self, epoch, logs=None):
      # 清掉上一次累積的 confusion matrix
      self.mean_iou.reset_state()


    def on_epoch_end(self, epoch, logs=None):
        conf_matrix = self.mean_iou.total_cm.numpy()
        inter      = np.diag(conf_matrix)            # [conf[0,0], conf[1,1]]
        gt_sum     = conf_matrix.sum(axis=1)          # 每行：真實各類總數
        pred_sum   = conf_matrix.sum(axis=0)          # 每列：預測各類總數
        union      = gt_sum + pred_sum - inter
        per_iou    = inter / (union + 1e-8)

        print(f"\nEpoch {epoch+1} per-class IoU:")
        print(f"  - 背景 (0) IoU: {per_iou[0]:.4f}")
        print(f"  - 前景 (1) IoU: {per_iou[1]:.4f}")

# %%
class BinarizedIoU(tf.keras.metrics.MeanIoU):
    def update_state(self, y_true, y_pred, sample_weight=None):
        y_pred = tf.cast(y_pred > 0.5, tf.int32)
        y_true = tf.cast(y_true, tf.int32)
        return super().update_state(y_true, y_pred, sample_weight)

# %%
def dice_loss(y_true, y_pred, smooth=1.0):
    """
    Dice 損失函數
    參數：
      y_true: 真實遮罩，shape=(batch, H, W, 1)，dtype=tf.float32
      y_pred: 模型預測，shape=(batch, H, W, 1)，dtype=tf.float32
      smooth: 防止分母為零的小常數
    回傳：
      loss: 1 - Dice coefficient，越小越好
    """
    # 扁平化成向量以計算交集與總和
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    # 交集
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    # Dice coefficient
    dice_coeff = (2.0 * intersection + smooth) / (
        tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth
    )
    # 損失即 1 - Dice
    return 1.0 - dice_coeff

# %%
OUTPUT_CLASSES = 2

model = unetpp_model()
# 定義 MeanIoU、平均誤差公分、誤差在0.5cm內準確率、誤差在1.0cm內準確率
iou_metric = BinarizedIoU(num_classes=2, name='mean_iou')
mean_error = MeanErrorCM(name='mean_error_cm')
acc_0_5cm = AccuracyWithinThreshold(0.5, name='acc_within_0.5cm')
acc_1_0cm = AccuracyWithinThreshold(1.0, name='acc_within_1.0cm')

metrics   = [iou_metric, mean_error, acc_0_5cm, acc_1_0cm]

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=dice_loss,     # 使用自訂的 Dice 損失
    metrics=metrics,
    run_eagerly=True
)
# Out:
# <ipython-input-11-5f21d56de8da>:12: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = tf.keras.applications.MobileNetV2(input_tensor=inputs,

# %% [markdown]
# 绘制最终的模型架构：

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %% [markdown]
# ## 訓練模型

# %%
EPOCHS = 5
histories = []  # 用來存每一折的 history

for fold in range(1, NUM_FOLDS + 1):
    print(f"\n===== Fold {fold} / {NUM_FOLDS} =====")

    # 驗證集：不做增強
    val_ds = build_dataset(f"{BASE_DIR}/Fold{fold}/val",
                           f"{BASE_DIR}/Fold{fold}/valannot",
                           augment_data=False)

    # 訓練集：其他四折合併並做增強
    train_ds = None
    for k in range(1, NUM_FOLDS + 1):
        if k == fold:
            continue
        ds_k = build_dataset(f"{BASE_DIR}/Fold{k}/train",
                             f"{BASE_DIR}/Fold{k}/trainannot",
                             augment_data=True)
        train_ds = ds_k if train_ds is None else train_ds.concatenate(ds_k)

    train_ds = train_ds.shuffle(1000) \
                   .batch(BATCH_SIZE) \
                   .prefetch(AUTOTUNE)

    val_ds   = val_ds.batch(BATCH_SIZE) \
                    .prefetch(AUTOTUNE)


    callbacks = [
      EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True),
      ModelCheckpoint(filepath=f"best_model_fold{fold}.weights.h5",
                      monitor='val_loss',
                      save_best_only=True,
                      save_weights_only=True),
      PerClassIoUCallback(iou_metric),
    ]



    # 開始訓練
    history = model.fit(
      train_ds,
      validation_data=val_ds,
      epochs=EPOCHS,
      callbacks=callbacks
    )
    histories.append(history)  # 把這折的結果丟進列表
# Out:
# ===== Fold 1 / 5 =====
# Epoch 1/5
# /usr/local/lib/python3.11/dist-packages/keras/src/optimizers/base_optimizer.py:774: UserWarning: Gradients do not exist for variables ['block_6_depthwise/kernel', 'block_6_depthwise_BN/gamma', 'block_6_depthwise_BN/beta', 'block_6_project/kernel', 'block_6_project_BN/gamma', 'block_6_project_BN/beta', 'block_7_expand/kernel', 'block_7_expand_BN/gamma', 'block_7_expand_BN/beta', 'block_7_depthwise/kernel', 'block_7_depthwise_BN/gamma', 'block_7_depthwise_BN/beta', 'block_7_project/kernel', 'block_7_project_BN/gamma', 'block_7_project_BN/beta', 'block_8_expand/kernel', 'block_8_expand_BN/gamma', 'block_8_expand_BN/beta', 'block_8_depthwise/kernel', 'block_8_depthwise_BN/gamma', 'block_8_depthwise_BN/beta', 'block_8_project/kernel', 'block_8_project_BN/gamma', 'block_8_project_BN/beta', 'block_9_expand/kernel', 'block_9_expand_BN/gamma', 'block_9_expand_BN/beta', 'block_9_depthwise/kernel', 'block_9_depthwise_BN/gamma', 'block_9_depthwise_BN/beta', 'block_9_project/kernel', 'block_9_project_BN/gamma', 'block_9_project_BN/beta', 'block_10_expand/kernel', 'block_10_expand_BN/gamma', 'block_10_expand_BN/beta', 'block_10_depthwise/kernel', 'block_10_depthwise_BN/gamma', 'block_10_depthwise_BN/beta', 'block_10_project/kernel', 'block_10_project_BN/gamma', 'block_10_project_BN/beta', 'block_11_expand/kernel', 'block_11_expand_BN/gamma', 'block_11_expand_BN/beta', 'block_11_depthwise/kernel', 'block_11_depthwise_BN/gamma', 'block_11_depthwise_BN/beta', 'block_11_project/kernel', 'block_11_project_BN/gamma', 'block_11_project_BN/beta', 'block_12_expand/kernel', 'block_12_expand_BN/gamma', 'block_12_expand_BN/beta', 'block_12_depthwise/kernel', 'block_12_depthwise_BN/gamma', 'block_12_depthwise_BN/beta', 'block_12_project/kernel', 'block_12_project_BN/gamma', 'block_12_project_BN/beta', 'block_13_expand/kernel', 'block_13_expand_BN/gamma', 'block_13_expand_BN/beta', 'block_13_depthwise/kernel', 'block_13_depthwise_BN/gamma', 'block_13_depthwise_BN/beta', 'block_13_project/kernel', 'block_13_project_BN/gamma', 'block_13_project_BN/beta', 'block_14_expand/kernel', 'block_14_expand_BN/gamma', 'block_14_expand_BN/beta', 'block_14_depthwise/kernel', 'block_14_depthwise_BN/gamma', 'block_14_depthwise_BN/beta', 'block_14_project/kernel', 'block_14_project_BN/gamma', 'block_14_project_BN/beta', 'block_15_expand/kernel', 'block_15_expand_BN/gamma', 'block_15_expand_BN/beta', 'block_15_depthwise/kernel', 'block_15_depthwise_BN/gamma', 'block_15_depthwise_BN/beta', 'block_15_project/kernel', 'block_15_project_BN/gamma', 'block_15_project_BN/beta', 'block_16_expand/kernel', 'block_16_expand_BN/gamma', 'block_16_expand_BN/beta', 'block_16_depthwise/kernel', 'block_16_depthwise_BN/gamma', 'block_16_depthwise_BN/beta', 'block_16_project/kernel'] when minimizing the loss. If using `model.compile()`, did you forget to provide a `loss` argument?
#   warnings.warn(
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.9626 - mean_error_cm: 0.0065 - mean_iou: 0.2805
# Epoch 1 per-class IoU:
#   - 背景 (0) IoU: 0.9762
#   - 前景 (1) IoU: 0.1057
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 553s 2s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.9624 - mean_error_cm: 0.0065 - mean_iou: 0.2811 - val_acc_within_0.5cm: 0.0638 - val_acc_within_1.0cm: 0.1915 - val_loss: 0.8396 - val_mean_error_cm: 4.0757e-04 - val_mean_iou: 0.5409
# Epoch 2/5
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.9339 - mean_error_cm: 0.0042 - mean_iou: 0.4139
# Epoch 2 per-class IoU:
#   - 背景 (0) IoU: 0.9817
#   - 前景 (1) IoU: 0.0618
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 140s 1s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.9338 - mean_error_cm: 0.0042 - mean_iou: 0.4141 - val_acc_within_0.5cm: 0.0638 - val_acc_within_1.0cm: 0.1489 - val_loss: 0.8952 - val_mean_error_cm: 2.7490e-04 - val_mean_iou: 0.5217
# Epoch 3/5
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.9076 - mean_error_cm: 0.0028 - mean_iou: 0.4669
# Epoch 3 per-class IoU:
#   - 背景 (0) IoU: 0.9838
#   - 前景 (1) IoU: 0.0197
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 140s 1s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.9076 - mean_error_cm: 0.0028 - mean_iou: 0.4670 - val_acc_within_0.5cm: 0.0000e+00 - val_acc_within_1.0cm: 0.1277 - val_loss: 0.9619 - val_mean_error_cm: 2.3710e-04 - val_mean_iou: 0.5018
# Epoch 4/5
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.8879 - mean_error_cm: 0.0023 - mean_iou: 0.4963
# Epoch 4 per-class IoU:
#   - 背景 (0) IoU: 0.9838
#   - 前景 (1) IoU: 0.0111
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.8878 - mean_error_cm: 0.0023 - mean_iou: 0.4964 - val_acc_within_0.5cm: 0.0000e+00 - val_acc_within_1.0cm: 0.0000e+00 - val_loss: 0.9789 - val_mean_error_cm: 2.7678e-04 - val_mean_iou: 0.4974
#
# ===== Fold 2 / 5 =====
# Epoch 1/5
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.9357 - mean_error_cm: 0.0043 - mean_iou: 0.4094
# Epoch 1 per-class IoU:
#   - 背景 (0) IoU: 0.9825
#   - 前景 (1) IoU: 0.0795
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 235s 2s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.9357 - mean_error_cm: 0.0043 - mean_iou: 0.4095 - val_acc_within_0.5cm: 0.0426 - val_acc_within_1.0cm: 0.2340 - val_loss: 0.8606 - val_mean_error_cm: 2.6385e-04 - val_mean_iou: 0.5310
# Epoch 2/5
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.9142 - mean_error_cm: 0.0032 - mean_iou: 0.4538
# Epoch 2 per-class IoU:
#   - 背景 (0) IoU: 0.9826
#   - 前景 (1) IoU: 0.0655
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.9142 - mean_error_cm: 0.0032 - mean_iou: 0.4539 - val_acc_within_0.5cm: 0.0851 - val_acc_within_1.0cm: 0.2340 - val_loss: 0.8830 - val_mean_error_cm: 2.5058e-04 - val_mean_iou: 0.5241
# Epoch 3/5
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.8976 - mean_error_cm: 0.0026 - mean_iou: 0.4822
# Epoch 3 per-class IoU:
#   - 背景 (0) IoU: 0.9846
#   - 前景 (1) IoU: 0.0746
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 198s 1s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.8975 - mean_error_cm: 0.0026 - mean_iou: 0.4822 - val_acc_within_0.5cm: 0.2128 - val_acc_within_1.0cm: 0.3830 - val_loss: 0.9056 - val_mean_error_cm: 3.4865e-04 - val_mean_iou: 0.5296
# Epoch 4/5
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.8843 - mean_error_cm: 0.0022 - mean_iou: 0.5015
# Epoch 4 per-class IoU:
#   - 背景 (0) IoU: 0.9846
#   - 前景 (1) IoU: 0.0625
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 140s 1s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.8843 - mean_error_cm: 0.0022 - mean_iou: 0.5015 - val_acc_within_0.5cm: 0.1064 - val_acc_within_1.0cm: 0.2766 - val_loss: 0.9257 - val_mean_error_cm: 3.8689e-04 - val_mean_iou: 0.5235
#
# ===== Fold 3 / 5 =====
# Epoch 1/5
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.9146 - mean_error_cm: 0.0032 - mean_iou: 0.4531
# Epoch 1 per-class IoU:
#   - 背景 (0) IoU: 0.9829
#   - 前景 (1) IoU: 0.0429
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 157s 2s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.9145 - mean_error_cm: 0.0032 - mean_iou: 0.4532 - val_acc_within_0.5cm: 0.0851 - val_acc_within_1.0cm: 0.2340 - val_loss: 0.9187 - val_mean_error_cm: 2.4618e-04 - val_mean_iou: 0.5129
# Epoch 2/5
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.9015 - mean_error_cm: 0.0026 - mean_iou: 0.4806
# Epoch 2 per-class IoU:
#   - 背景 (0) IoU: 0.9837
#   - 前景 (1) IoU: 0.0317
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 140s 1s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.9015 - mean_error_cm: 0.0026 - mean_iou: 0.4807 - val_acc_within_0.5cm: 0.0638 - val_acc_within_1.0cm: 0.1277 - val_loss: 0.9489 - val_mean_error_cm: 3.0502e-04 - val_mean_iou: 0.5077
# Epoch 3/5
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.8866 - mean_error_cm: 0.0023 - mean_iou: 0.5001
# Epoch 3 per-class IoU:
#   - 背景 (0) IoU: 0.9837
#   - 前景 (1) IoU: 0.0237
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 140s 1s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.8866 - mean_error_cm: 0.0023 - mean_iou: 0.5001 - val_acc_within_0.5cm: 0.0000e+00 - val_acc_within_1.0cm: 0.0000e+00 - val_loss: 0.9637 - val_mean_error_cm: 3.5115e-04 - val_mean_iou: 0.5037
# Epoch 4/5
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.8749 - mean_error_cm: 0.0021 - mean_iou: 0.5142
# Epoch 4 per-class IoU:
#   - 背景 (0) IoU: 0.9835
#   - 前景 (1) IoU: 0.0422
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 140s 1s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.8748 - mean_error_cm: 0.0021 - mean_iou: 0.5142 - val_acc_within_0.5cm: 0.0000e+00 - val_acc_within_1.0cm: 0.0000e+00 - val_loss: 0.9425 - val_mean_error_cm: 3.6936e-04 - val_mean_iou: 0.5128
#
# ===== Fold 4 / 5 =====
# Epoch 1/5
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.9001 - mean_error_cm: 0.0026 - mean_iou: 0.4794
# Epoch 1 per-class IoU:
#   - 背景 (0) IoU: 0.9841
#   - 前景 (1) IoU: 0.0356
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 159s 2s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.9000 - mean_error_cm: 0.0026 - mean_iou: 0.4795 - val_acc_within_0.5cm: 0.0833 - val_acc_within_1.0cm: 0.2292 - val_loss: 0.9422 - val_mean_error_cm: 2.9378e-04 - val_mean_iou: 0.5099
# Epoch 2/5
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.8870 - mean_error_cm: 0.0023 - mean_iou: 0.5010
# Epoch 2 per-class IoU:
#   - 背景 (0) IoU: 0.9835
#   - 前景 (1) IoU: 0.0723
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 139s 1s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.8869 - mean_error_cm: 0.0023 - mean_iou: 0.5010 - val_acc_within_0.5cm: 0.0000e+00 - val_acc_within_1.0cm: 0.0000e+00 - val_loss: 0.8995 - val_mean_error_cm: 3.3458e-04 - val_mean_iou: 0.5279
# Epoch 3/5
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.8764 - mean_error_cm: 0.0021 - mean_iou: 0.5122
# Epoch 3 per-class IoU:
#   - 背景 (0) IoU: 0.9837
#   - 前景 (1) IoU: 0.0723
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 138s 1s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.8764 - mean_error_cm: 0.0021 - mean_iou: 0.5122 - val_acc_within_0.5cm: 0.0000e+00 - val_acc_within_1.0cm: 0.0000e+00 - val_loss: 0.9025 - val_mean_error_cm: 3.4705e-04 - val_mean_iou: 0.5280
# Epoch 4/5
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.8628 - mean_error_cm: 0.0019 - mean_iou: 0.5249
# Epoch 4 per-class IoU:
#   - 背景 (0) IoU: 0.9838
#   - 前景 (1) IoU: 0.0410
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.8627 - mean_error_cm: 0.0019 - mean_iou: 0.5249 - val_acc_within_0.5cm: 0.0000e+00 - val_acc_within_1.0cm: 0.0000e+00 - val_loss: 0.9450 - val_mean_error_cm: 3.7284e-04 - val_mean_iou: 0.5124
# Epoch 5/5
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.8531 - mean_error_cm: 0.0017 - mean_iou: 0.5325
# Epoch 5 per-class IoU:
#   - 背景 (0) IoU: 0.9840
#   - 前景 (1) IoU: 0.0296
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 138s 1s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.8530 - mean_error_cm: 0.0017 - mean_iou: 0.5326 - val_acc_within_0.5cm: 0.0000e+00 - val_acc_within_1.0cm: 0.0000e+00 - val_loss: 0.9562 - val_mean_error_cm: 3.3970e-04 - val_mean_iou: 0.5068
#
# ===== Fold 5 / 5 =====
# Epoch 1/5
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.8767 - mean_error_cm: 0.0021 - mean_iou: 0.5121
# Epoch 1 per-class IoU:
#   - 背景 (0) IoU: 0.9838
#   - 前景 (1) IoU: 0.0858
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 176s 2s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.8766 - mean_error_cm: 0.0021 - mean_iou: 0.5121 - val_acc_within_0.5cm: 0.0000e+00 - val_acc_within_1.0cm: 0.0000e+00 - val_loss: 0.8880 - val_mean_error_cm: 3.4649e-04 - val_mean_iou: 0.5348
# Epoch 2/5
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.8660 - mean_error_cm: 0.0019 - mean_iou: 0.5234
# Epoch 2 per-class IoU:
#   - 背景 (0) IoU: 0.9845
#   - 前景 (1) IoU: 0.0464
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 137s 1s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.8660 - mean_error_cm: 0.0019 - mean_iou: 0.5235 - val_acc_within_0.5cm: 0.0000e+00 - val_acc_within_1.0cm: 0.0000e+00 - val_loss: 0.9391 - val_mean_error_cm: 3.5605e-04 - val_mean_iou: 0.5155
# Epoch 3/5
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.8550 - mean_error_cm: 0.0017 - mean_iou: 0.5325
# Epoch 3 per-class IoU:
#   - 背景 (0) IoU: 0.9845
#   - 前景 (1) IoU: 0.0301
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.8549 - mean_error_cm: 0.0017 - mean_iou: 0.5326 - val_acc_within_0.5cm: 0.0000e+00 - val_acc_within_1.0cm: 0.0000e+00 - val_loss: 0.9572 - val_mean_error_cm: 3.3761e-04 - val_mean_iou: 0.5073
# Epoch 4/5
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.8409 - mean_error_cm: 0.0016 - mean_iou: 0.5432
# Epoch 4 per-class IoU:
#   - 背景 (0) IoU: 0.9845
#   - 前景 (1) IoU: 0.0344
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 139s 1s/step - acc_within_0.5cm: 0.0000e+00 - acc_within_1.0cm: 0.0000e+00 - loss: 0.8408 - mean_error_cm: 0.0016 - mean_iou: 0.5433 - val_acc_within_0.5cm: 0.0000e+00 - val_acc_within_1.0cm: 0.0000e+00 - val_loss: 0.9530 - val_mean_error_cm: 3.4899e-04 - val_mean_iou: 0.5094

# %%
metrics = ['loss','mean_iou', 'mean_error_cm', 'acc_within_0.5cm', 'acc_within_1.0cm']

fig, axes = plt.subplots(
    nrows=1,
    ncols=len(metrics),
    figsize=(5 * len(metrics), 4)
)

for ax, m in zip(axes, metrics):
    for fold_idx, h in enumerate(histories, start=1):
        train_vals = h.history[m]              # 該折的訓練指標
        val_vals   = h.history[f'val_{m}']     # 該折的驗證指標

        # 一條實線和一條虛線，分別代表訓練和驗證
        ax.plot(h.epoch, train_vals,  label=f'Fold{fold_idx} Train')
        ax.plot(h.epoch, val_vals,   '--', label=f'Fold{fold_idx} Val')

    ax.set_title(m)
    ax.set_xlabel('Epoch')
    ax.set_ylabel(m)
    ax.legend(fontsize='small', ncol=2)  # 讓圖例分兩行顯示，不至於擠在一起

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 做出预测

# %%
def extract_endpoint_np(mask_np):
    """
    取最靠近病人腳端 (y 最大) 的前景像素座標。
    mask_np : (H,W) or (H,W,1) ndarray, 值 0 / 1
    回傳   : (x, y)；若無前景 → (-1,-1)
    """
    if mask_np.ndim == 3:
        mask_np = mask_np.squeeze(-1)

    ys, xs = tf.where(mask_np > 0.5).numpy().T
    if len(ys) == 0:
        return (-1, -1)

    idx = ys.argmax()          # y 最大
    return (int(xs[idx]), int(ys[idx]))

# %%
def plot_batch_with_preds(image_batch, mask_batch, model, count=3):
    """
    顯示 [Image / Ground-Truth / Prediction]，並把
    - 綠色圓點標 GT 端點
    - 紅色叉叉標 Pred 端點
    """
    # 1. 預測 + 二值化
    preds = tf.where(model.predict(image_batch) >= 0.5, 1, 0)

    for i in range(min(count, image_batch.shape[0])):
        img  = image_batch[i]
        gt   = mask_batch[i]
        prd  = preds[i]

        # 還原影像亮度
        if tf.reduce_max(img) <= 1.0:
            img = tf.cast(img * 255.0, tf.uint8)
        else:
            img = tf.cast(img, tf.uint8)

        # 去掉 channel
        if gt.ndim == 3: gt  = tf.squeeze(gt,  axis=-1)
        if prd.ndim == 3: prd = tf.squeeze(prd, axis=-1)

        # 端點
        gt_pt  = extract_endpoint_np(gt.numpy())
        prd_pt = extract_endpoint_np(prd.numpy())

        fig, axs = plt.subplots(1, 3, figsize=(12, 4))

        # ------------ Image ------------
        axs[0].imshow(img.numpy())
        if gt_pt != (-1, -1):
            axs[0].scatter(*gt_pt, s=60, c='lime', marker='o', label='GT')
        if prd_pt != (-1, -1):
            axs[0].scatter(*prd_pt, s=60, c='red',  marker='x', label='Pred')
        axs[0].set_title("Image + Endpoints")
        axs[0].axis("off")
        axs[0].legend(loc='lower right', fontsize='small')

        # ------------ GT mask ------------
        axs[1].imshow(gt.numpy(), cmap='gray')
        axs[1].set_title("Ground Truth")
        axs[1].axis("off")

        # ------------ Pred mask ------------
        axs[2].imshow(prd.numpy(), cmap='gray')
        axs[2].set_title("Prediction")
        axs[2].axis("off")

        plt.tight_layout()
        plt.show()

# %%
test_ds = build_dataset(f"{BASE_DIR}/Fold{1}/test",
                             f"{BASE_DIR}/Fold{1}/testannot",
                             augment_data=False).batch(BATCH_SIZE)
for image_batch, mask_batch in train_ds.take(1):
    plot_batch_with_preds(image_batch, mask_batch, model, count=3)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import convolve

# ——————————————————————————————
# 1. 定義：從二值化 mask 找到 skeleton 的 endpoint
def find_endpoint(binary_mask):
    """
    binary_mask: 2D numpy array (0/1)
    回傳 (x,y)，代表 tube 最末端的像素座標
    """
    # 3x3 卷積核：中心為 0，其餘為 1
    kernel = np.array([[1,1,1],
                       [1,0,1],
                       [1,1,1]], dtype=np.uint8)
    # 計算每個像素周圍有幾個 foreground 鄰居
    nbrs = convolve(binary_mask.astype(np.uint8), kernel, mode='constant', cval=0)
    # endpoint 則是：自己是 1，且 neighbor count==1
    end_pts = np.logical_and(binary_mask==1, nbrs==1)
    ys, xs = np.where(end_pts)
    if len(xs) > 0:
        # 以下示例選擇 y 座標最大的那個點（即最靠下端）
        idx = np.argmax(ys)
        return xs[idx], ys[idx]
    else:
        # 若沒 skeleton 端點，就退而求其次：選 mask 中 y 最大的位置
        ys_all, xs_all = np.where(binary_mask==1)
        idx = np.argmax(ys_all)
        return xs_all[idx], ys_all[idx]

# ——————————————————————————————
# 2. 建資料集並分 batch
test_ds = build_dataset(
    f"{BASE_DIR}/Fold1/test",
    f"{BASE_DIR}/Fold1/testannot",
    augment_data=False
).batch(BATCH_SIZE)

# ——————————————————————————————
# 3. 逐 batch 預測並畫圖，標註端點
for image_batch, mask_batch in test_ds.take(1):
    # model.predict 回傳每個像素的機率
    pred_probs = model.predict(image_batch)

    # 我們只畫前 3 張
    for i in range(3):
        img = image_batch[i].numpy().squeeze()       # 原始影像
        gt = mask_batch[i].numpy().squeeze()          # 真實 mask
        pred = (pred_probs[i].squeeze() > 0.5).astype(np.uint8)  # 二值化預測 mask

        # 找端點
        gt_x, gt_y   = find_endpoint(gt)
        pred_x, pred_y = find_endpoint(pred)

        # 建立三欄 subplot
        fig, axes = plt.subplots(1, 3, figsize=(12, 4))

        # (1) 原圖
        axes[0].imshow(img, cmap='gray')
        axes[0].set_title('Image')
        axes[0].axis('off')

        # (2) Ground Truth Mask + 紅點 (G)
        axes[1].imshow(gt, cmap='viridis')
        axes[1].scatter(gt_x, gt_y, s=60, c='red', marker='o')
        axes[1].annotate('G', (gt_x, gt_y), color='white',
                         xytext=(5, -10), textcoords='offset points')
        axes[1].set_title('Ground Truth Mask')
        axes[1].axis('off')

        # (3) Predicted Mask + 黃點 (Y)
        axes[2].imshow(pred, cmap='viridis')
        axes[2].scatter(pred_x, pred_y, s=60, c='white', marker='o')
        axes[2].annotate('Y', (pred_x, pred_y), color='red',
                         xytext=(5, -10), textcoords='offset points')
        axes[2].set_title('Predicted Mask')
        axes[2].axis('off')

        plt.tight_layout()
        plt.show()
